# %% [markdown]
# ## **Water Quality**

# %% [markdown]
# **Importing Necessary libraries:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv(r"C:\Users\mythi\Downloads\waterQuality1.csv")
data
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32   21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
# ...

# %%
data.shape
# Out:
# (7999, 21)

# %% [markdown]
# **Replacing #NUM! with nan**

# %%
data = data.replace({'#NUM!':np.nan})
data.head()
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# ...

# %%
data=data.dropna()

# %%
data.shape
# Out:
# (7996, 21)

# %%
data.isnull().sum()
# Out:
# aluminium      0
# ammonia        0
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        0
# dtype: int64

# %%
data['is_safe'].value_counts()
# Out:
# 0    7084
# 1     912
# Name: is_safe, dtype: int64

# %% [markdown]
# **Changing datatype**

# %%
data['ammonia']=data['ammonia'].astype(float)
data['is_safe']=data['is_safe'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7996 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7996 non-null   float64
#  1   ammonia      7996 non-null   float64
#  2   arsenic      7996 non-null   float64
#  3   barium       7996 non-null   float64
#  4   cadmium      7996 non-null   float64
#  5   chloramine   7996 non-null   float64
#  6   chromium     7996 non-null   float64
#  7   copper       7996 non-null   float64
#  8   flouride     7996 non-null   float64
#  9   bacteria     7996 non-null   float64
#  10  viruses      7996 non-null   float64
#  11  lead         7996 non-null   float64
#  12  nitrates     7996 non-null   float64
#  13  nitrites     7996 non-null   float64
#  14  mercury      7996 non-null   float64
#  15  perchlorate  7996 non-null   float64
#  16  radium       7996 non-null   float64
#  17  selenium     7996 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['aluminium', 'ammonia', 'arsenic', 'barium', 'cadmium', 'chloramine',
#        'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead',
#        'nitrates', 'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium',
#        'silver', 'uranium', 'is_safe'],
#       dtype='object')

# %%
x=data[['aluminium', 'ammonia', 'arsenic', 'barium', 'cadmium', 'chloramine',
       'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead',
       'nitrates', 'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium',
       'silver', 'uranium']]
y=data[['is_safe']]

# %%
y
# Out:
#       is_safe
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# ...       ...
# 7994        1
# 7995        1
# 7996        1
# 7997        1
# 7998        1
#
# [7996 rows x 1 columns]

# %%
x.shape
# Out:
# (7996, 20)

# %%
y.shape
# Out:
# (7996, 1)

# %% [markdown]
# **Seperating train and test:**

# %%
import sklearn 
from sklearn.model_selection import train_test_split

# %%
# Splitting the 'train' and 'test' data.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)

# %%
x_train
# Out:
#       aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 3488       0.02    27.25     0.37    1.21    0.030        7.81      0.65
# 2639       0.00    25.99     0.01    3.06    0.002        3.36      0.63
# 1793       3.56    26.72     0.67    1.95    0.070        3.35      0.83
# 1358       1.14     1.97     0.31    3.45    0.100        3.44      0.25
# 3005       0.09    14.37     0.16    3.74    0.080        0.83      0.43
# ...         ...      ...      ...     ...      ...         ...       ...
# 7938       0.10     0.34     0.07    0.93    0.080        0.12      0.05
# 5192       0.01    23.35     0.01    0.09    0.070        0.03      0.09
# 3980       0.02    17.22     0.19    1.69    0.080        4.94      0.29
# 235        1.40     5.43     0.04    3.14    0.008        0.83      0.52
# 5157       0.02    18.85     0.06    0.01    0.060        0.08      0.09
#
#       copper  flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# ...

# %%
# Shape of 'x_train' and 'y_train'.

print(x_train.shape, y_train.shape)

# Shape of 'x_test' and 'y_test'.

print(x_test.shape, y_test.shape)
# Out:
# (5997, 20) (5997, 1)
# (1999, 20) (1999, 1)

# %% [markdown]
# **Rescalling numerical columns of training data:**

# %%
x_train_num = x_train.select_dtypes(include=['int32','float64']) # Seperating the Numerical columns
x_train_num
# Out:
#       aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 3488       0.02    27.25     0.37    1.21    0.030        7.81      0.65
# 2639       0.00    25.99     0.01    3.06    0.002        3.36      0.63
# 1793       3.56    26.72     0.67    1.95    0.070        3.35      0.83
# 1358       1.14     1.97     0.31    3.45    0.100        3.44      0.25
# 3005       0.09    14.37     0.16    3.74    0.080        0.83      0.43
# ...         ...      ...      ...     ...      ...         ...       ...
# 7938       0.10     0.34     0.07    0.93    0.080        0.12      0.05
# 5192       0.01    23.35     0.01    0.09    0.070        0.03      0.09
# 3980       0.02    17.22     0.19    1.69    0.080        4.94      0.29
# 235        1.40     5.43     0.04    3.14    0.008        0.83      0.52
# 5157       0.02    18.85     0.06    0.01    0.060        0.08      0.09
#
#       copper  flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()   
x_train_rescaled = pd.DataFrame(scaler.fit_transform(x_train_num), 
                                    columns = x_train_num.columns, 
                                    index = x_train_num.index)
x_train_rescaled.head()
# Out:
#       aluminium   ammonia   arsenic    barium   cadmium  chloramine  chromium  \
# 3488  -0.514134  1.468316  0.822770 -0.299758 -0.359974    2.197555  1.485231
# 2639  -0.529894  1.326597 -0.601242  1.221243 -1.133060    0.459348  1.411274
# 1793   2.275377  1.408704  2.009446  0.308642  0.744436    0.455441  2.150846
# 1358   0.368423 -1.375060  0.585434  1.541887  1.572743    0.490596  0.006086
# 3005  -0.458974  0.019634 -0.007904  1.780314  1.020538   -0.528892  0.671701
#
#         copper  flouride  bacteria   viruses      lead  nitrates  nitrites  \
# 3488 -1.136289  0.162629  0.027998 -0.854497 -1.697286  0.340828  0.290059
# 2639  0.687481 -0.988234  1.880428  1.627845 -0.114211 -0.396297  0.677417
# 1793  0.043797 -1.011251  1.728589  1.495099 -0.888541  0.629190  1.927528
# 1358 -0.645864 -0.021509 -0.974136 -0.857152 -0.303491  1.058128  1.029561
# 3005  0.871391 -1.517630  1.060500  0.911019  0.608498  0.153393  1.188026
#
# ...

# %% [markdown]
# **Rescalling numerical columns of test data:**

# %%
x_test_num = x_test.select_dtypes(include=['float64']) # Seperating the Numerical columns
x_test_num
# Out:
#       aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 7981       0.09     0.15    0.090    0.14    0.050        0.12      0.07
# 5563       0.10     0.51    0.090    0.34    0.070        0.04      0.08
# 2879       0.01     0.40    0.001    2.15    0.008        7.18      0.11
# 5247       0.07     0.49    0.010    0.02    0.030        0.07      0.02
# 2202       0.08    21.30    0.001    0.33    0.004        2.45      0.67
# ...         ...      ...      ...     ...      ...         ...       ...
# 1098       0.09    13.08    0.050    3.26    0.010        4.90      0.33
# 4846       0.03    19.06    0.070    0.62    0.070        0.16      0.04
# 2532       0.09    11.43    0.010    1.04    0.001        6.81      0.87
# 5395       0.09    27.17    0.030    0.60    0.050        0.24      0.06
# 4884       0.09     3.37    0.020    1.75    0.050        0.44      0.05
#
#       copper  flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# ...

# %%
x_test_rescaled = pd.DataFrame(scaler.transform(x_test_num), 
                                   columns = x_test_num.columns, 
                                   index = x_test_num.index)

x_test_rescaled.head()
# Out:
#       aluminium   ammonia   arsenic    barium   cadmium  chloramine  chromium  \
# 7981  -0.458974 -1.579765 -0.284795 -1.179473  0.192231   -0.806224 -0.659529
# 5563  -0.451094 -1.539273 -0.284795 -1.015040  0.744436   -0.837472 -0.622551
# 2879  -0.522014 -1.551646 -0.636843  0.473075 -0.967399    1.951472 -0.511615
# 5247  -0.474734 -1.541523 -0.601242 -1.278133 -0.359974   -0.825754 -0.844422
# 2202  -0.466854  0.799088 -0.636843 -1.023262 -1.077840    0.103894  1.559188
#
#         copper  flouride  bacteria   viruses      lead  nitrates  nitrites  \
# 7981 -1.136289  0.669009 -0.974136 -0.867772 -0.664845 -1.457829 -0.590300
# 5563  1.729636  1.658751 -0.518621 -0.865117  0.247144  0.198449 -1.065694
# 2879 -0.431302  0.645992  0.179836 -0.859807 -0.406735  0.306585 -0.026870
# 5247  1.193233 -1.471596 -0.974136 -0.867772 -0.406735  0.047059 -1.558696
# 2202  0.840739 -0.251681  1.333809  1.149961  0.178314 -0.023229  0.606989
#
# ...

# %%
print(X_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (5997, 40) (1999, 20)
# (5997, 1) (1999, 1)

# %% [markdown]
# **Importing required libraries:**

# %%
import tensorflow
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras import regularizers

# %% [markdown]
# **Creating 1st model**

# %% [markdown]
# **Creating Dense layer**

# %%
model=Sequential()
model.add(Dense(5,activation='relu',input_dim=20))
model.add(Dense(3,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 5)                 105
#
#  dense_4 (Dense)             (None, 3)                 18
#
#  dense_5 (Dense)             (None, 1)                 4
#
# ...
# Total params: 127
# Trainable params: 127
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile**

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# **Fitting**

# %%
save=model.fit(x_train,y_train,batch_size=10,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 480/480 [==============================] - 5s 4ms/step - loss: 1.0717 - accuracy: 0.6748 - val_loss: 0.4115 - val_accuracy: 0.8733
# Epoch 2/100
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3760 - accuracy: 0.8818 - val_loss: 0.3977 - val_accuracy: 0.8783
# Epoch 3/100
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3645 - accuracy: 0.8828 - val_loss: 0.3801 - val_accuracy: 0.8792
# Epoch 4/100
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3402 - accuracy: 0.8833 - val_loss: 0.3515 - val_accuracy: 0.8792
# Epoch 5/100
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3164 - accuracy: 0.8841 - val_loss: 0.3264 - val_accuracy: 0.8792
# Epoch 6/100
# 480/480 [==============================] - 1s 2ms/step - loss: 0.3007 - accuracy: 0.8843 - val_loss: 0.3063 - val_accuracy: 0.8792
# Epoch 7/100
# ...

# %%
t1=save.history['loss']
cv1=save.history['val_loss']

# %%
plt.plot(t1,label="training_loss")
plt.plot(cv1,label="crossval_loss")
plt.legend()

# %%
y_pred=model.evaluate(x_test,y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1972 - accuracy: 0.9270

# %%
y_pred
# Out:
# [0.19718267023563385, 0.9269635081291199]

# %% [markdown]
# **Creating 2nd model**

# %% [markdown]
# **Creating Dense layer**

# %%
model1=Sequential()
model1.add(Dense(6,activation='tanh',input_dim=20))
model1.add(Dense(4,activation='tanh'))
model1.add(Dense(2,activation='tanh'))
model1.add(Dense(1,activation='sigmoid'))

# %%
model1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 6)                 126
#
#  dense_11 (Dense)            (None, 4)                 28
#
#  dense_12 (Dense)            (None, 2)                 10
#
#  dense_13 (Dense)            (None, 1)                 3
#
# ...
# Total params: 167
# Trainable params: 167
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile**

# %%
model1.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# **Fitting**

# %%
save1=model1.fit(x_train,y_train,batch_size=10,epochs=100,validation_split=0.1)
# Out:
# Epoch 1/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1503 - accuracy: 0.9448 - val_loss: 0.1607 - val_accuracy: 0.9400
# Epoch 2/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1513 - accuracy: 0.9450 - val_loss: 0.1528 - val_accuracy: 0.9417
# Epoch 3/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1479 - accuracy: 0.9483 - val_loss: 0.1632 - val_accuracy: 0.9383
# Epoch 4/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1475 - accuracy: 0.9466 - val_loss: 0.1644 - val_accuracy: 0.9400
# Epoch 5/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1506 - accuracy: 0.9457 - val_loss: 0.1758 - val_accuracy: 0.9383
# Epoch 6/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1492 - accuracy: 0.9452 - val_loss: 0.1530 - val_accuracy: 0.9417
# Epoch 7/100
# ...

# %%
tl1=save1.history["loss"]
cvl1=save1.history["val_loss"]

# %%
plt.plot(tl1,label="training_loss")
plt.plot(cvl1,label="crossval_loss")
plt.legend()

# %%
y_pred1 = model1.evaluate(x_test, y_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1216 - accuracy: 0.9560

# %%
y_pred1
# Out:
# [0.12155473232269287, 0.9559779763221741]

# %% [markdown]
# **Creating 3rd model**

# %% [markdown]
# **Creating Dense layer**

# %%
model2=Sequential()
model2.add(Dense(10,activation='relu',input_dim=20,kernel_initializer='he_uniform'))
model2.add(Dense(8,activation='relu',kernel_initializer='he_uniform'))
model2.add(Dense(6,activation='relu',kernel_initializer='he_uniform'))
model2.add(Dense(1,activation='sigmoid',kernel_initializer='he_uniform'))

# %%
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_14 (Dense)            (None, 10)                210
#
#  dense_15 (Dense)            (None, 8)                 88
#
#  dense_16 (Dense)            (None, 6)                 54
#
#  dense_17 (Dense)            (None, 1)                 7
#
# ...
# Total params: 359
# Trainable params: 359
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile**

# %%
model2.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# **Fitting**

# %%
save2=model2.fit(x_train,y_train,batch_size=10,epochs=100,validation_split=0.3)
# Out:
# Epoch 1/100
# 420/420 [==============================] - 2s 2ms/step - loss: 0.3911 - accuracy: 0.8737 - val_loss: 0.3645 - val_accuracy: 0.8750
# Epoch 2/100
# 420/420 [==============================] - 1s 2ms/step - loss: 0.3394 - accuracy: 0.8832 - val_loss: 0.3288 - val_accuracy: 0.8794
# Epoch 3/100
# 420/420 [==============================] - 1s 2ms/step - loss: 0.3180 - accuracy: 0.8837 - val_loss: 0.3035 - val_accuracy: 0.8828
# Epoch 4/100
# 420/420 [==============================] - 1s 2ms/step - loss: 0.2976 - accuracy: 0.8883 - val_loss: 0.2853 - val_accuracy: 0.8861
# Epoch 5/100
# 420/420 [==============================] - 1s 2ms/step - loss: 0.2861 - accuracy: 0.8890 - val_loss: 0.2739 - val_accuracy: 0.8900
# Epoch 6/100
# 420/420 [==============================] - 1s 2ms/step - loss: 0.2811 - accuracy: 0.8904 - val_loss: 0.2698 - val_accuracy: 0.8939
# Epoch 7/100
# ...

# %%
tl2=save2.history["loss"]
cvl2=save2.history["val_loss"]

# %%
plt.plot(tl2,label="training_loss")
plt.plot(cvl2,label="crossval_loss")
plt.legend()

# %%
y_pred2 = model2.evaluate(x_test, y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1949 - accuracy: 0.9185

# %%
y_pred2
# Out:
# [0.194926455616951, 0.9184592366218567]

# %% [markdown]
# **Creating 4th model**

# %% [markdown]
# **Creating Dense layer**

# %%
model3=Sequential()
model3.add(Dense(10,activation='relu',input_dim=20,kernel_initializer='glorot_uniform'))
model3.add(Dense(8,activation='relu',kernel_initializer='glorot_uniform'))
model3.add(Dense(6,activation='relu',kernel_initializer='glorot_uniform'))
model3.add(Dense(1,activation='sigmoid',kernel_initializer='glorot_uniform'))

# %%
model3.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 10)                210
#
#  dense_19 (Dense)            (None, 8)                 88
#
#  dense_20 (Dense)            (None, 6)                 54
#
#  dense_21 (Dense)            (None, 1)                 7
#
# ...
# Total params: 359
# Trainable params: 359
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile**

# %%
model3.compile(optimizer='Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# **Fitting**

# %%
 save3 = model3.fit(x_train, y_train, batch_size = 15, epochs = 150, validation_split= 0.1)
# Out:
# Epoch 1/150
# 360/360 [==============================] - 2s 2ms/step - loss: 0.4564 - accuracy: 0.7764 - val_loss: 0.3760 - val_accuracy: 0.8767
# Epoch 2/150
# 360/360 [==============================] - 1s 2ms/step - loss: 0.3257 - accuracy: 0.8840 - val_loss: 0.3366 - val_accuracy: 0.8767
# Epoch 3/150
# 360/360 [==============================] - 1s 2ms/step - loss: 0.2889 - accuracy: 0.8857 - val_loss: 0.2905 - val_accuracy: 0.8817
# Epoch 4/150
# 360/360 [==============================] - 1s 2ms/step - loss: 0.2727 - accuracy: 0.8922 - val_loss: 0.2837 - val_accuracy: 0.8800
# Epoch 5/150
# 360/360 [==============================] - 1s 2ms/step - loss: 0.2658 - accuracy: 0.8961 - val_loss: 0.2640 - val_accuracy: 0.8900
# Epoch 6/150
# 360/360 [==============================] - 1s 2ms/step - loss: 0.2602 - accuracy: 0.8981 - val_loss: 0.2612 - val_accuracy: 0.8950
# Epoch 7/150
# ...

# %%
tl3 = save3.history["loss"]
cvl3 = save3.history["val_loss"]

# %%
plt.plot(tl3,label="training_loss")
plt.plot(cvl3,label="crossval_loss")
plt.legend()

# %%
y_pred3 = model3.evaluate(x_test, y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1767 - accuracy: 0.9345

# %%
y_pred3
# Out:
# [0.17674562335014343, 0.9344672560691833]

# %% [markdown]
# **Creating 5th model**

# %% [markdown]
# **Creating Dense layer**

# %%
model4=Sequential()
model4.add(Dense(14,activation='tanh',input_dim=20,kernel_initializer='glorot_uniform'))
model4.add(Dense(7,activation='tanh',kernel_initializer='glorot_uniform'))
model4.add(Dense(1,activation='sigmoid'))

# %%
model4.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_32 (Dense)            (None, 14)                294
#
#  dense_33 (Dense)            (None, 7)                 105
#
#  dense_34 (Dense)            (None, 1)                 8
#
# ...
# Total params: 407
# Trainable params: 407
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile**

# %%
model4.compile(optimizer='Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# **Fitting**

# %%
save4 = model4.fit(x_train, y_train, batch_size = 10, epochs = 100, validation_split= 0.1)
# Out:
# Epoch 1/100
# 540/540 [==============================] - 4s 2ms/step - loss: 0.3680 - accuracy: 0.8692 - val_loss: 0.3283 - val_accuracy: 0.8783
# Epoch 2/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2981 - accuracy: 0.8860 - val_loss: 0.2842 - val_accuracy: 0.8817
# Epoch 3/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2784 - accuracy: 0.8929 - val_loss: 0.2729 - val_accuracy: 0.8883
# Epoch 4/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2672 - accuracy: 0.8974 - val_loss: 0.2668 - val_accuracy: 0.8917
# Epoch 5/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2575 - accuracy: 0.9049 - val_loss: 0.2631 - val_accuracy: 0.8933
# Epoch 6/100
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2484 - accuracy: 0.9057 - val_loss: 0.2514 - val_accuracy: 0.9033
# Epoch 7/100
# ...

# %%
tl4 = save4.history["loss"]
cvl4 = save4.history["val_loss"]

# %%
plt.plot(tl4,label="training_loss")
plt.plot(cvl4,label="crossval_loss")
plt.legend()

# %%
y_pred4 = model4.evaluate(x_test, y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1325 - accuracy: 0.9490

# %%
y_pred4
# Out:
# [0.13253960013389587, 0.9489744901657104]

# %% [markdown]
# **Conclusion:**

# %% [markdown]
# - from the above models, for the 2nd model we got the best accuracy
# - accuracy score : 0.9559779763221741
# - optimizer : Adam
# - loss : binary_crossentropy
# - epochs : 100
# - activation : tanh
